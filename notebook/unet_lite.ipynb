# %%
from pytorch_lightning import Trainer
from torch.nn import MSELoss

from dataset.cat2000 import Cat2000
from models.saliency_model import SaliencyModel
from models.unet_lite import UNetLite

datamodule = Cat2000()
print(datamodule)
criterion = MSELoss()
model = UNetLite()
model.decoder_32_out.use_skip_connection = False
lit_model = SaliencyModel(model, MSELoss())
trainer = Trainer()
trainer.fit(lit_model, datamodule=datamodule)
trainer.test(lit_model, datamodule=datamodule)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# C:\Users\sumx21t\projects\illust-salmap\.venv\Lib\site-packages\pytorch_lightning\trainer\connectors\logger_connector\logger_connector.py:75: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `pytorch_lightning` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default
# C:\Users\sumx21t\projects\illust-salmap\.venv\Lib\site-packages\pytorch_lightning\loops\utilities.py:72: `max_epochs` was not set. Setting it to 1000 epochs. To train without an epoch limit, set `max_epochs=-1`.
# [INFO] Downloading from http://saliency.mit.edu/trainSet.zip...
# type
# 100%|██████████| 692M/692M [05:54<00:00, 1.95MB/s]
# [INFO] Downloaded successfully to C:\Users\sumx21t\projects\illust-salmap\notebook\data\cat2000\trainSet.zip.
# [INFO] Extracting...
# [INFO] Unzipping C:\Users\sumx21t\projects\illust-salmap\notebook\data\cat2000\trainSet.zip...
# [INFO] Extracting into C:\Users\sumx21t\projects\illust-salmap\notebook\data\cat2000\trainSet...
# 100%|██████████| 8085/8085 [00:05<00:00, 1519.13file/s]
# [INFO] Extracted successfully to C:\Users\sumx21t\projects\illust-salmap\notebook\data\cat2000\trainSet.
# [INFO] Dataset already exists at C:\Users\sumx21t\projects\illust-salmap\notebook\data\cat2000\trainSet.zip, skipping download.
# [INFO] Dataset already extracted at C:\Users\sumx21t\projects\illust-salmap\notebook\data\cat2000\trainSet, skipping extraction.
#
#   | Name      | Type                    | Params | Mode
# --------------------------------------------------------------
# 0 | model     | UNetLite                | 19.5 M | train
# 1 | criterion | MSELoss                 | 0      | train
# 2 | kl_div    | LambdaInputTransformer  | 0      | train
# 3 | sim       | LambdaInputTransformer  | 0      | train
# 4 | scc       | LambdaInputTransformer  | 0      | train
# 5 | auroc     | BinaryTargetTransformer | 0      | train
# --------------------------------------------------------------
# 19.5 M    Trainable params
# 0         Non-trainable params
# 19.5 M    Total params
# 77.914    Total estimated model params size (MB)
# 94        Modules in train mode
# 0         Modules in eval mode
# Epoch 0: 100%|██████████| 50/50 [05:53<00:00,  0.14it/s, v_num=0, train_loss=0.701]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/13 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/13 [00:00<?, ?it/s]
# Validation DataLoader 0:   8%|▊         | 1/13 [00:03<00:40,  0.29it/s]
# Validation DataLoader 0:  15%|█▌        | 2/13 [00:06<00:35,  0.31it/s]
# Validation DataLoader 0:  23%|██▎       | 3/13 [00:09<00:32,  0.31it/s]
# Validation DataLoader 0:  31%|███       | 4/13 [00:12<00:28,  0.31it/s]
# Validation DataLoader 0:  38%|███▊      | 5/13 [00:15<00:25,  0.32it/s]
# Validation DataLoader 0:  46%|████▌     | 6/13 [00:19<00:22,  0.32it/s]
# Validation DataLoader 0:  54%|█████▍    | 7/13 [00:22<00:18,  0.32it/s]
# Validation DataLoader 0:  62%|██████▏   | 8/13 [00:25<00:15,  0.32it/s]
# Validation DataLoader 0:  69%|██████▉   | 9/13 [00:28<00:12,  0.32it/s]
# Validation DataLoader 0:  77%|███████▋  | 10/13 [00:31<00:09,  0.32it/s]
# Validation DataLoader 0:  85%|████████▍ | 11/13 [00:34<00:06,  0.32it/s]
# Validation DataLoader 0:  92%|█████████▏| 12/13 [00:38<00:03,  0.32it/s]
# Validation DataLoader 0: 100%|██████████| 13/13 [00:39<00:00,  0.33it/s]
# Epoch 0: 100%|██████████| 50/50 [07:06<00:00,  0.12it/s, v_num=0, train_loss=0.701, val_loss=0.633, val_kl_div=0.0711, val_sim=1.21e+3, val_scc=-0.000133, val_auroc=0.588]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.124528326..0.109447114].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.11776278..0.09435972].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.65656877..0.78967714].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6141283..0.9999998].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.56804967..0.99999917].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6366768..0.6000146].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.61466634..0.6968656].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6154655..0.9999997].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6347876..0.6768526].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.67437243..0.98436224].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6760862..0.9977149].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6164308..0.8821582].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.64512604..0.99999934].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.69452804..0.9999997].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6848559..0.9999998].
# Epoch 1:  80%|████████  | 40/50 [04:53<01:13,  0.14it/s, v_num=0, train_loss=0.698, val_loss=0.633, val_kl_div=0.0711, val_sim=1.21e+3, val_scc=-0.000133, val_auroc=0.588]
# Detected KeyboardInterrupt, attempting graceful shutdown ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\projects\illust-salmap\.venv\Lib\site-packages\pytorch_lightning\trainer\call.py:47, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      46         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 47     return trainer_fn(*args, **kwargs)
#      49 except _TunerExitException:
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\pytorch_lightning\trainer\trainer.py:574, in Trainer._fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     568 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     569     self.state.fn,
#     570     ckpt_path,
#     571     model_provided=True,
#     572     model_connected=self.lightning_module is not None,
#     573 )
# --> 574 self._run(model, ckpt_path=ckpt_path)
#     576 assert self.state.stopped
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\pytorch_lightning\trainer\trainer.py:981, in Trainer._run(self, model, ckpt_path)
#     978 # ----------------------------
#     979 # RUN THE TRAINER
#     980 # ----------------------------
# --> 981 results = self._run_stage()
#     983 # ----------------------------
#     984 # POST-Training CLEAN UP
#     985 # ----------------------------
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\pytorch_lightning\trainer\trainer.py:1025, in Trainer._run_stage(self)
#    1024 with torch.autograd.set_detect_anomaly(self._detect_anomaly):
# -> 1025     self.fit_loop.run()
#    1026 return None
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\pytorch_lightning\loops\fit_loop.py:205, in _FitLoop.run(self)
#     204 self.on_advance_start()
# --> 205 self.advance()
#     206 self.on_advance_end()
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\pytorch_lightning\loops\fit_loop.py:363, in _FitLoop.advance(self)
#     362 assert self._data_fetcher is not None
# --> 363 self.epoch_loop.run(self._data_fetcher)
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\pytorch_lightning\loops\training_epoch_loop.py:140, in _TrainingEpochLoop.run(self, data_fetcher)
#     139 try:
# --> 140     self.advance(data_fetcher)
#     141     self.on_advance_end(data_fetcher)
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\pytorch_lightning\loops\training_epoch_loop.py:250, in _TrainingEpochLoop.advance(self, data_fetcher)
#     248 if trainer.lightning_module.automatic_optimization:
#     249     # in automatic optimization, there can only be one optimizer
# --> 250     batch_output = self.automatic_optimization.run(trainer.optimizers[0], batch_idx, kwargs)
#     251 else:
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\pytorch_lightning\loops\optimization\automatic.py:190, in _AutomaticOptimization.run(self, optimizer, batch_idx, kwargs)
#     185 # ------------------------------
#     186 # BACKWARD PASS
#     187 # ------------------------------
#     188 # gradient update with accumulated gradients
#     189 else:
# --> 190     self._optimizer_step(batch_idx, closure)
#     192 result = closure.consume_result()
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\pytorch_lightning\loops\optimization\automatic.py:268, in _AutomaticOptimization._optimizer_step(self, batch_idx, train_step_and_backward_closure)
#     267 # model hook
# --> 268 call._call_lightning_module_hook(
#     269     trainer,
#     270     "optimizer_step",
#     271     trainer.current_epoch,
#     272     batch_idx,
#     273     optimizer,
#     274     train_step_and_backward_closure,
#     275 )
#     277 if not should_accumulate:
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\pytorch_lightning\trainer\call.py:167, in _call_lightning_module_hook(trainer, hook_name, pl_module, *args, **kwargs)
#     166 with trainer.profiler.profile(f"[LightningModule]{pl_module.__class__.__name__}.{hook_name}"):
# --> 167     output = fn(*args, **kwargs)
#     169 # restore current_fx when nested context
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\pytorch_lightning\core\module.py:1306, in LightningModule.optimizer_step(self, epoch, batch_idx, optimizer, optimizer_closure)
#    1282 r"""Override this method to adjust the default way the :class:`~pytorch_lightning.trainer.trainer.Trainer` calls
#    1283 the optimizer.
#    1284
#    (...)
#    1304
#    1305 """
# -> 1306 optimizer.step(closure=optimizer_closure)
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\pytorch_lightning\core\optimizer.py:153, in LightningOptimizer.step(self, closure, **kwargs)
#     152 assert self._strategy is not None
# --> 153 step_output = self._strategy.optimizer_step(self._optimizer, closure, **kwargs)
#     155 self._on_after_step()
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\pytorch_lightning\strategies\strategy.py:238, in Strategy.optimizer_step(self, optimizer, closure, model, **kwargs)
#     237 assert isinstance(model, pl.LightningModule)
# --> 238 return self.precision_plugin.optimizer_step(optimizer, model=model, closure=closure, **kwargs)
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\pytorch_lightning\plugins\precision\precision.py:122, in Precision.optimizer_step(self, optimizer, model, closure, **kwargs)
#     121 closure = partial(self._wrap_closure, model, optimizer, closure)
# --> 122 return optimizer.step(closure=closure, **kwargs)
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\torch\optim\optimizer.py:487, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     483             raise RuntimeError(
#     484                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     485             )
# --> 487 out = func(*args, **kwargs)
#     488 self._optimizer_step_code()
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\torch\optim\optimizer.py:91, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      90     torch._dynamo.graph_break()
# ---> 91     ret = func(self, *args, **kwargs)
#      92 finally:
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\torch\optim\adam.py:202, in Adam.step(self, closure)
#     201     with torch.enable_grad():
# --> 202         loss = closure()
#     204 for group in self.param_groups:
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\pytorch_lightning\plugins\precision\precision.py:108, in Precision._wrap_closure(self, model, optimizer, closure)
#     101 """This double-closure allows makes sure the ``closure`` is executed before the ``on_before_optimizer_step``
#     102 hook is called.
#     103
#    (...)
#     106
#     107 """
# --> 108 closure_result = closure()
#     109 self._after_closure(model, optimizer)
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\pytorch_lightning\loops\optimization\automatic.py:144, in Closure.__call__(self, *args, **kwargs)
#     142 @override
#     143 def __call__(self, *args: Any, **kwargs: Any) -> Optional[Tensor]:
# --> 144     self._result = self.closure(*args, **kwargs)
#     145     return self._result.loss
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     115 with ctx_factory():
# --> 116     return func(*args, **kwargs)
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\pytorch_lightning\loops\optimization\automatic.py:129, in Closure.closure(self, *args, **kwargs)
#     126 @override
#     127 @torch.enable_grad()
#     128 def closure(self, *args: Any, **kwargs: Any) -> ClosureResult:
# --> 129     step_output = self._step_fn()
#     131     if step_output.closure_loss is None:
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\pytorch_lightning\loops\optimization\automatic.py:317, in _AutomaticOptimization._training_step(self, kwargs)
#     315 trainer = self.trainer
# --> 317 training_step_output = call._call_strategy_hook(trainer, "training_step", *kwargs.values())
#     318 self.trainer.strategy.post_training_step()  # unused hook - call anyway for backward compatibility
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\pytorch_lightning\trainer\call.py:319, in _call_strategy_hook(trainer, hook_name, *args, **kwargs)
#     318 with trainer.profiler.profile(f"[Strategy]{trainer.strategy.__class__.__name__}.{hook_name}"):
# --> 319     output = fn(*args, **kwargs)
#     321 # restore current_fx when nested context
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\pytorch_lightning\strategies\strategy.py:390, in Strategy.training_step(self, *args, **kwargs)
#     389     return self._forward_redirection(self.model, self.lightning_module, "training_step", *args, **kwargs)
# --> 390 return self.lightning_module.training_step(*args, **kwargs)
#
# File ~\projects\illust-salmap\models\saliency_model.py:44, in SaliencyModel.training_step(self, batch, batch_idx)
#      43 self.scc(predict, ground_truth)
# ---> 44 self.auroc(predict, ground_truth)
#      46 self.log("train_loss", loss, prog_bar=True)
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\torchmetrics\wrappers\transformations.py:76, in MetricInputTransformer.forward(self, *args, **kwargs)
#      75 args = self._wrap_transform(*args)
# ---> 76 return self.wrapped_metric.forward(*args, **kwargs)
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\torchmetrics\metric.py:316, in Metric.forward(self, *args, **kwargs)
#     315 else:
# --> 316     self._forward_cache = self._forward_reduce_state_update(*args, **kwargs)
#     318 return self._forward_cache
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\torchmetrics\metric.py:386, in Metric._forward_reduce_state_update(self, *args, **kwargs)
#     385 self.update(*args, **kwargs)
# --> 386 batch_val = self.compute()
#     388 # reduce batch and global state
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\torchmetrics\metric.py:700, in Metric._wrap_compute.<locals>.wrapped_func(*args, **kwargs)
#     695 with self.sync_context(
#     696     dist_sync_fn=self.dist_sync_fn,
#     697     should_sync=self._to_sync,
#     698     should_unsync=self._should_unsync,
#     699 ):
# --> 700     value = _squeeze_if_scalar(compute(*args, **kwargs))
#     701     # clone tensor to avoid in-place operations after compute, altering already computed results
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\torchmetrics\classification\auroc.py:125, in BinaryAUROC.compute(self)
#     124 state = (dim_zero_cat(self.preds), dim_zero_cat(self.target)) if self.thresholds is None else self.confmat
# --> 125 return _binary_auroc_compute(state, self.thresholds, self.max_fpr)
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\torchmetrics\functional\classification\auroc.py:89, in _binary_auroc_compute(state, thresholds, max_fpr, pos_label)
#      83 def _binary_auroc_compute(
#      84     state: Union[Tensor, tuple[Tensor, Tensor]],
#      85     thresholds: Optional[Tensor],
#      86     max_fpr: Optional[float] = None,
#      87     pos_label: int = 1,
#      88 ) -> Tensor:
# ---> 89     fpr, tpr, _ = _binary_roc_compute(state, thresholds, pos_label)
#      90     if max_fpr is None or max_fpr == 1 or fpr.sum() == 0 or tpr.sum() == 0:
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\torchmetrics\functional\classification\roc.py:54, in _binary_roc_compute(state, thresholds, pos_label)
#      53 else:
# ---> 54     fps, tps, thres = _binary_clf_curve(preds=state[0], target=state[1], pos_label=pos_label)
#      55     # Add an extra threshold position to make sure that the curve starts at (0, 0)
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\torchmetrics\functional\classification\precision_recall_curve.py:73, in _binary_clf_curve(preds, target, sample_weights, pos_label)
#      72 target = (target == pos_label).to(torch.long)
# ---> 73 tps = _cumsum(target * weight, dim=0)[threshold_idxs]
#      75 if sample_weights is not None:
#      76     # express fps as a cumsum to ensure fps is increasing even in
#      77     # the presence of floating point errors
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\torchmetrics\utilities\data.py:209, in _cumsum(x, dim, dtype)
#     206     return torch.bincount(x, minlength=minlength)
# --> 209 def _cumsum(x: Tensor, dim: Optional[int] = 0, dtype: Optional[torch.dtype] = None) -> Tensor:
#     210     if torch.are_deterministic_algorithms_enabled() and x.is_cuda and x.is_floating_point() and sys.platform != "win32":
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 14
#      12 lit_model = SaliencyModel(model, MSELoss())
#      13 trainer = Trainer()
# ---> 14 trainer.fit(lit_model, datamodule=datamodule)
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\pytorch_lightning\trainer\trainer.py:538, in Trainer.fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     536 self.state.status = TrainerStatus.RUNNING
#     537 self.training = True
# --> 538 call._call_and_handle_interrupt(
#     539     self, self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     540 )
#
# File ~\projects\illust-salmap\.venv\Lib\site-packages\pytorch_lightning\trainer\call.py:64, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      62     if isinstance(launcher, _SubprocessScriptLauncher):
#      63         launcher.kill(_get_sigkill_signal())
# ---> 64     exit(1)
#      66 except BaseException as exception:
#      67     _interrupt(trainer, exception)
#
# NameError: name 'exit' is not defined

# %%
from torch.nn import MSELoss

from dataset.cat2000 import Cat2000
from models.saliency_model import SaliencyModel
from models.unet_lite import UNetLite

datamodule = Cat2000()
print(datamodule)
criterion = MSELoss()
model = UNetLite()
lit_model = SaliencyModel(model, MSELoss())
trainer = Trainer()
trainer.test(lit_model, datamodule=datamodule)
